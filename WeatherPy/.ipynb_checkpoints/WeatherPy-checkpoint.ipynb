# %% [markdown]
# # WeatherPy
# ----

# %%
import pandas as pd
import json
import requests
import random
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import datetime
from scipy.stats import linregress
from api_keys import weather_api_key
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
# Define city list
city_list=[]

# Loop through random coordinates to generate city list
for city in range(2000):
    lat=random.randrange(-90,90)
    lng=random.randrange(-180,180)
    city = citipy.nearest_city(lat,lng)
    city_list.append(city.city_name)
# Check city list length
len(city_list)
# Out:
# 2000

# %%
# Drop duplicate cities from city list
city_list = list(set(city_list))

# Check city list length with out duplicate cities
len(city_list)
# Out:
# 754

# %%
# Define lists for city data
City=[]
Lat=[]
Lng=[]
Max_Temp=[]
Humidity=[]
Cloudiness=[]
Wind_Speed=[]
Country=[]
Date=[]

#data={"City":[City],"Lat":[Lat],"Lng":[Lng],"Max_Temp":[Max_Temp],"Humidity":[Humidity],"Cloudiness":[Cloudiness],"Wind_Speed":[Wind_Speed],"Country":[Country],"Date":[Date]}

# %%
# Set weather api url
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define city to test weather api url
city="petaluma"   
    
query_url = url + "appid=" + weather_api_key + "&q=" + city
print(f"Getting data for {city}")
weather_response = requests.get(query_url)
weather_json = weather_response.json()
weather_json
# Out:
# Getting data for petaluma
# {'coord': {'lon': -122.64, 'lat': 38.23},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 291.65,
#   'feels_like': 291.69,
#   'temp_min': 290.15,
#   'temp_max': 294.82,
#   'pressure': 1015,
#   'humidity': 67},
#  'visibility': 10000,
#  'wind': {'speed': 0.94, 'deg': 278},
#  'clouds': {'all': 90},
#  'dt': 1601619446,
#  'sys': {'type': 1,
#   'id': 5152,
#   'country': 'US',
#   'sunrise': 1601561202,
#   'sunset': 1601603588},
#  'timezone': -25200,
#  'id': 5382232,
#  'name': 'Petaluma',
#  'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Define weather api url
url = "http://api.openweathermap.org/data/2.5/weather?"

# City counter 
x=1

# Store today's date 
today= datetime.date.today()
date=today.strftime("%m/%d/%Y")

# Loop through city_list to retrieve city data from weather api url
for city in city_list:    
    query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + "imperial"
    try:
        print(f"Getting data for city #{x}|{city}")
        
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        
        City.append(weather_json['name'])
        Lat.append(weather_json['coord']['lat'])
        Lng.append(weather_json['coord']['lon'])
        Max_Temp.append(weather_json['main']['temp_max'])
        Humidity.append(weather_json['main']['humidity'])
        Cloudiness.append(weather_json['clouds']['all'])
        Wind_Speed.append(weather_json['wind']['speed'])
        Country.append(weather_json['sys']['country'])
        Date.append(weather_json['dt'])
        x=x+1
    except:
        print("data not found")
# Out:
# Getting data for city #1|flin flon
# Getting data for city #2|dolores
# Getting data for city #3|orlik
# Getting data for city #4|jesup
# Getting data for city #5|san felipe
# Getting data for city #6|kita
# Getting data for city #7|sorvag
# data not found
# Getting data for city #7|villazon
# Getting data for city #8|kushima
# Getting data for city #9|zeya
# Getting data for city #10|dali
# Getting data for city #11|nikolayevsk-na-amure
# Getting data for city #12|ulaangom
# Getting data for city #13|bolungarvik
# data not found
# Getting data for city #13|belle glade
# Getting data for city #14|terrasini
# Getting data for city #15|nizhniy tagil
# Getting data for city #603|burica
# data not found
# Getting data for city #603|abhar
# Getting data for city #604|sertanopolis
# Getting data for city #605|viligili
# data not found
# Getting data for city #605|falmouth
# Getting data for city #606|atasu
# Getting data for city #607|manicaragua
# Getting data for city #608|zyryanka
# Getting data for city #609|bay-ang
# Getting data for city #610|mporokoso
# Getting data for city #611|sao felix do xingu
# Getting data for city #612|saint-philippe
# Getting data for city #613|san patricio
# Getting data for city #614|ketchikan
# Getting data for city #615|saleaula
# data not found
# Getting data for city #615|louisbourg
# data not found
# Getting data for city #615|meyungs
# data not found
# Getting data for city #615|penzance
# data not found
# Getting data for city #615|magway
# Getting data for city #616|mumbwa
# Getting data for city #617|bur gabo
# data not found
# Getting data for city #617|pahrump
# Getting data for city #618|rocha
# Getting data for city #619|jega
# Getting data for city #620|batagay-alyta
# Getting data for city #621|pontes e lacerda
# Getting data for city #622|hami
# Getting data for city #623|ruteng
# Getting data for city #624|kutum
# Getting data for city #625|porto velho
# Getting data for city #626|chisec
# Getting data for city #627|raga
# Getting data for city #628|beringovskiy
# Getting data for city #629|jacala
# Getting data for city #630|aran
# Getting data for city #631|vestmannaeyjar
# Getting data for city #632|boysun
# Getting data for city #633|ilulissat
# Getting data for city #634|urusha
# Getting data for city #635|airai
# Getting data for city #636|antofagasta
# data not found
# Getting data for city #636|vologda
# Getting data for city #637|aksarayskiy
# data not found
# Getting data for city #637|paamiut
# Getting data for city #638|san alberto
# Getting data for city #639|san benito abad
# Getting data for city #640|broome
# Getting data for city #641|hasaki
# Getting data for city #642|tarudant
# data not found
# Getting data for city #642|bilma
# Getting data for city #643|martapura
# Getting data for city #644|georgiyevskoye
# Getting data for city #645|longyearbyen
# Getting data for city #646|goderich
# Getting data for city #647|dhankuta
# Getting data for city #648|codrington
# Getting data for city #649|oum hadjer
# Getting data for city #650|karratha
# Getting data for city #651|beyneu
# Getting data for city #652|arroyos y esteros
# Getting data for city #653|kurchum
# Getting data for city #654|gorno-chuyskiy
# data not found
# Getting data for city #654|conceicao do araguaia
# Getting data for city #655|trairi
# Getting data for city #656|pacific grove
# Getting data for city #657|korem
# Getting data for city #658|port augusta
# Getting data for city #659|tingi
# Getting data for city #660|tsihombe
# data not found
# Getting data for city #660|anamur

# %%
# Create dataframe from city data
data={"City":City,"Lat":Lat,"Lng":Lng,"Max_Temp":Max_Temp,"Humidity":Humidity,"Cloudiness":Cloudiness,"Wind_Speed":Wind_Speed,"Country":Country,"Date":Date}
data_df=pd.DataFrame(data, columns=['City','Lat','Lng','Max_Temp','Humidity','Cloudiness','Wind_Speed','Country','Date'])

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export city data into .csv file
data_df.to_csv (r'..\output_data\cities_data.csv', index = False, header=True)

# Display dataframe
data_df
# Out:
#               City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0        Flin Flon  54.77 -101.86     38.30        80         100        4.52
# 1          Dolores -36.31  -57.68     39.61        91           0        8.46
# 2            Orlik  52.52   99.83     30.83        73         100        4.99
# 3            Jesup  31.61  -81.89     60.80        87           1        4.97
# 4       San Felipe  10.34  -68.74     71.56        91          95        2.21
# ..             ...    ...     ...       ...       ...         ...         ...
# 655  Pacific Grove  36.62 -121.92     64.40        67          90        4.07
# 656          Korem  12.51   39.52     67.86        46           2       10.16
# 657   Port Augusta -32.50  137.77     89.60        15           0       21.92
# 658          Tingi -11.30   35.03     83.82        39           5        6.29
# 659         Anamur  36.08   32.84     82.40        54          20        6.93
#
#     Country        Date
# 0        CA  1601619716
# 1        AR  1601619720
# 2        RU  1601619721
# 3        US  1601619722
# 4        VE  1601619626
# ..      ...         ...
# 655      US  1601627628
# 656      ET  1601627647
# 657      AU  1601627574
# 658      TZ  1601627649
# 659      TR  1601627651
#
# [660 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----

# %%
# Drop city with humidity over 100%
data_clean=data_df.drop( data_df[ data_df['Humidity'] > 100 ].index , inplace=False)

# Display clean dataframe
data_clean
# Out:
#               City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0        Flin Flon  54.77 -101.86     38.30        80         100        4.52
# 1          Dolores -36.31  -57.68     39.61        91           0        8.46
# 2            Orlik  52.52   99.83     30.83        73         100        4.99
# 3            Jesup  31.61  -81.89     60.80        87           1        4.97
# 4       San Felipe  10.34  -68.74     71.56        91          95        2.21
# ..             ...    ...     ...       ...       ...         ...         ...
# 655  Pacific Grove  36.62 -121.92     64.40        67          90        4.07
# 656          Korem  12.51   39.52     67.86        46           2       10.16
# 657   Port Augusta -32.50  137.77     89.60        15           0       21.92
# 658          Tingi -11.30   35.03     83.82        39           5        6.29
# 659         Anamur  36.08   32.84     82.40        54          20        6.93
#
#     Country        Date
# 0        CA  1601619716
# 1        AR  1601619720
# 2        RU  1601619721
# 3        US  1601619722
# 4        VE  1601619626
# ..      ...         ...
# 655      US  1601627628
# 656      ET  1601627647
# 657      AU  1601627574
# 658      TZ  1601627649
# 659      TR  1601627651
#
# [660 rows x 9 columns]

# %% [markdown]
# ## Plot the Data

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Generate scatter plot
plt.scatter(data_clean["Lat"], data_clean["Max_Temp"])
plt.title(f"Latitude vs. Max Temperature {date}")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig('..\output_data\lat_vs_temp.png')
plt.show()

# %%
## There appears to be a fairly strong correlation between max temperature and how close a city it to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Generate scatter plot
plt.scatter(data_clean["Lat"], data_clean["Humidity"])
plt.title(f"Latitude vs. Humidity {date}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig('..\output_data\lat_vs_humidity.png')
plt.show()

# %%
## It appears as though, driest regions are located between 
## 20-40 degrees either north or south of the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Generate scatter plot
plt.scatter(data_clean["Lat"], data_clean["Cloudiness"])
plt.title(f"Latitude vs Cloudiness {date}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig('..\output_data\lat_vs_cloud.png')
plt.show()

# %%
## There does not seem to be an obvious correlation between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Generate scatter plot
plt.scatter(data_clean["Lat"], data_clean["Wind_Speed"])
plt.title(f"Latitude vs. Wind Speed {date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig('..\output_data\lat_vs_wind.png')
plt.show()

# %%
## There does not appear to be a strong correlation between latitude and wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# Create separate data frames for the northern and southern hemispheres
north_df=data_df.drop(data_df[data_df['Lat']<0].index,inplace=False)
south_df=data_df.drop(data_df[data_df['Lat']>0].index,inplace=False)
print(f"{len(north_df)} cities in our sample list are in the northern hemisphere")
print(f"{len(south_df)} cities in our sample list are in the southern hemisphere")
# Out:
# 461 cities in our sample list are in the northern hemisphere
# 199 cities in our sample list are in the southern hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Generate scatter plot
plt.scatter(north_df["Max_Temp"], north_df["Lat"])
plt.title(f"Max Temperature vs Latitude {date}")
plt.ylabel("Latitude")
plt.xlabel("Temperature (F)")

# Calculate regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df["Max_Temp"], north_df["Lat"])
regress_values = north_df["Max_Temp"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Calculate Pearson's correlation coefficient
correlation = st.pearsonr(north_df["Max_Temp"],north_df["Lat"])

# Plot regression
plt.plot(north_df["Max_Temp"],regress_values,"r-")
plt.annotate(line_eq,(15,0),fontsize=15,color="red")
plt.savefig(r'..\output_data\temp_vs_lat_north.png')

plt.show()

# %%
## There is a very strong negative correlation between max temp
## and distance away from the equator in the northern hemesphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Generate scatter plot
plt.scatter(south_df["Max_Temp"], south_df["Lat"])
plt.title(f"Max Temperature vs Latitude {date}")
plt.ylabel("Latitude")
plt.xlabel("Temperature (F)")

# Calculate regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df["Max_Temp"], south_df["Lat"])
regress_values = south_df["Max_Temp"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Calculate Pearson's correlation coefficient
correlation = st.pearsonr(south_df["Max_Temp"], south_df["Lat"])

# Plot regression
plt.plot(south_df["Max_Temp"],regress_values,"r-")
plt.annotate(line_eq,(70,-55),fontsize=15,color="red")
plt.savefig(r'..\output_data\temp_vs_lat_south.png')
plt.show()

# %%
## There is a strong negative correlation betweem max temp
## and distance from the equation in the southern hemesphere

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Generate scatter plot
plt.scatter(north_df["Humidity"], north_df["Lat"])
plt.title(f"Humidity vs. Latitude {date}")
plt.ylabel("Latitude")
plt.xlabel("Humidity (%)")

# Calculate regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df["Humidity"], north_df["Lat"])
regress_values = north_df["Humidity"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Calculate Pearson's correlation coefficient
correlation = st.pearsonr(north_df["Humidity"],north_df["Lat"])

# Plot regression
plt.plot(north_df["Humidity"],regress_values,"r-")
plt.annotate(line_eq,(5,5),fontsize=15,color="red")

plt.savefig('..\output_data\humdity_v_lat_north.png')
plt.show()

# %%
## The correlation between humidity and latitude appears to be weak 
## in the northern hemesphere

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Generate scatter plot
plt.scatter(south_df["Humidity"], south_df["Lat"])
plt.title(f"Humidity (%) vs Latitude {date}")
plt.ylabel("Latitude")
plt.xlabel("Humidity (%)")

# Calculate regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df["Humidity"], south_df["Lat"])
regress_values = south_df["Humidity"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Calculate Pearson's correlation coefficient
correlation = st.pearsonr(south_df["Humidity"],south_df["Lat"])

# Plot regression
plt.plot(south_df["Humidity"],regress_values,"r-")
plt.annotate(line_eq,(15, -52),fontsize=15,color="red")
plt.savefig('..\output_data\humdity_v_lat_south.png')
plt.show()

# %%
## The correlation bewtween humidity and latitude is very 
## weak in the southern hemesphere

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Generate scatter plot
plt.scatter(north_df["Cloudiness"], north_df["Lat"])
plt.title(f"Cloudiness vs Latitude {date}")
plt.ylabel("Latitude")
plt.xlabel("Cloudiness (%)")

# Calculate regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df["Cloudiness"], north_df["Lat"])
regress_values = north_df["Cloudiness"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Calculate Pearson's correlation coefficient
correlation = st.pearsonr(north_df["Cloudiness"],north_df["Lat"])

# Plot regression
plt.plot(north_df["Cloudiness"],regress_values,"r-")
plt.annotate(line_eq,(5, 75),fontsize=15,color="red")
plt.savefig('..\output_data\cloud_v_lat_north.png')
plt.show()

# %%
## The correlation between cloudiness and latitude is very 
## weak in the northern hemesphere

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Generate scatter plot
plt.scatter(south_df["Cloudiness"], south_df["Lat"])
plt.title(f"Cloudiness vs Latitude {date}")
plt.ylabel("Latitude")
plt.xlabel("Cloudiness (%)")

# Calculate regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df["Cloudiness"], south_df["Lat"])
regress_values = south_df["Cloudiness"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Calculate Pearson's correlation coefficient
correlation = st.pearsonr(south_df["Cloudiness"],south_df["Lat"])

# Plot regression
plt.plot(south_df["Cloudiness"],regress_values,"r-")
plt.annotate(line_eq,(0, -55),fontsize=15,color="red")
plt.savefig('..\output_data\cloud_v_lat_south.png')
plt.show()

# %%
## The correlation between cloudiness and latitude is very 
## weak in the southern hemesphere

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Generate scatter plot
plt.scatter(north_df["Wind_Speed"], north_df["Lat"])
plt.title(f"Wind_Speed (mph) vs. Latitude {date}")
plt.xlabel("Wind_Speed (mph)")
plt.ylabel("Latitude")

# Calculate regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df["Wind_Speed"], north_df["Lat"])
regress_values = north_df["Wind_Speed"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Calculate Pearson's coefficient
correWind_Speedion = st.pearsonr(north_df["Wind_Speed"],north_df["Lat"])

# Plot regression
plt.plot(north_df["Wind_Speed"],regress_values,"r-")
plt.annotate(line_eq,(16,2),fontsize=15,color="red")
plt.savefig('..\output_data\wind_v_lat_north.png')
plt.show()

# %%
## There appears to be a moderate correlation between wind speed and 
## latitude in the northern hemesphere

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Generate scatter plot
plt.scatter(south_df["Wind_Speed"], south_df["Lat"])
plt.title(f"Wind_Speed (mph) vs. Latitude {date}")
plt.xlabel("Wind_Speed (mph)")
plt.ylabel("Latitude")

# Calculate regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df["Wind_Speed"], south_df["Lat"])
regress_values = south_df["Wind_Speed"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Calculate Pearson's coefficient
correWind_Speedion = st.pearsonr(south_df["Wind_Speed"],south_df["Lat"])

# Plot regression
plt.plot(south_df["Wind_Speed"],regress_values,"r-")
plt.annotate(line_eq,(15, -50),fontsize=15,color="red")
plt.savefig('..\output_data\wind_v_lat_south.png')
plt.show()

# %%
## There appears to be a weaker correlation between wind speed and 
## latitude in the southern hemesphere than in the north.

# %%
### CONCLUSION

## From this data, we can conclude that the temperature of a region 
## is greately influenced by its distance from the equator; this is 
## reflected in data from both the northern and southern hemispheres.
## We can also conclude that wind speed in a region seems to only 
## light-moderate corrolation to its distance from the equator.
## Drier regions tend to be between 20-30 degrees from the equator in both
## the northern and southern hemispheres.
## Of all the weather factors considered in this analysis, cloudiness showed 
## to be influenced the least, and possibly not at all, by a regions distance from the equator.
